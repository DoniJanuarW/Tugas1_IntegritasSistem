# %% [markdown]
# <a href="https://colab.research.google.com/github/DoniJanuarW/Tugas1_IntegritasSistem/blob/main/Tugas1_IntegritasSistem_Doni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# Function to fetch data
def fetch_data():
    body = {"locations": [[9.70093, 48.477473], [9.207916, 49.153868], [37.573242, 55.801281], [115.663757, 38.106467]]}
    headers = {
        'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
        'Authorization': '5b3ce3597851110001cf6248a3356a672eab4600adb2ca42d468ad95',
        'Content-Type': 'application/json; charset=utf-8'
    }
    response = requests.post('https://api.openrouteservice.org/v2/matrix/driving-car', json=body, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        return None

# Function to display data in a DataFrame
def display_data(_):
    data = fetch_data()
    if data:
        durations = data.get("durations", [])
        df = pd.DataFrame(durations, columns=["Location 1", "Location 2", "Location 3", "Location 4"],
                           index=["Location 1", "Location 2", "Location 3", "Location 4"])
        display(df)
    else:
        print("Failed to fetch data")

# Button to fetch and display data
fetch_button = widgets.Button(description="Fetch Data")
fetch_button.on_click(display_data)
display(fetch_button)
# Out:
# Button(description='Fetch Data', style=ButtonStyle())
#             Location 1  Location 2  Location 3  Location 4
# Location 1        0.00     5712.20    91857.98   393037.28
# Location 2     5540.63        0.00    90605.23   391784.53
# Location 3    92071.28    90589.04        0.00   302958.53
# Location 4   393304.41   391822.16   302735.97        0.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35['Location 1'].plot(kind='hist', bins=20, title='Location 1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['Location 2'].plot(kind='hist', bins=20, title='Location 2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['Location 3'].plot(kind='hist', bins=20, title='Location 3')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['Location 4'].plot(kind='hist', bins=20, title='Location 4')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_39.plot(kind='scatter', x='Location 1', y='Location 2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_40.plot(kind='scatter', x='Location 2', y='Location 3', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41.plot(kind='scatter', x='Location 3', y='Location 4', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Location 1']
#   ys = series['Location 2']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_42.sort_values('Location 1', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Location 1')
# _ = plt.ylabel('Location 2')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Location 1']
#   ys = series['Location 3']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_43.sort_values('Location 1', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Location 1')
# _ = plt.ylabel('Location 3')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Location 1']
#   ys = series['Location 4']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_44.sort_values('Location 1', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Location 1')
# _ = plt.ylabel('Location 4')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Location 1']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Location 1'}, axis=1)
#               .sort_values('Location 1', ascending=True))
#   xs = counted['Location 1']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_45.sort_values('Location 1', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Location 1')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_46['Location 1'].plot(kind='line', figsize=(8, 4), title='Location 1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47['Location 2'].plot(kind='line', figsize=(8, 4), title='Location 2')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_48['Location 3'].plot(kind='line', figsize=(8, 4), title='Location 3')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49['Location 4'].plot(kind='line', figsize=(8, 4), title='Location 4')
# plt.gca().spines[['top', 'right']].set_visible(False)
